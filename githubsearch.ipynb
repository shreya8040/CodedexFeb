# %%
import pandas as pd

# %%
import requests
import time

# 🔑 Replace with your GitHub token
TOKEN = "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"

headers = {
    "Authorization": f"token {TOKEN}"
}

keyword = "generative art"
years = range(2010, 2024)

results = {}

for year in years:
    url = f"https://api.github.com/search/repositories?q={keyword}+created:{year}-01-01..{year}-12-31&per_page=1"
    
    response = requests.get(url, headers=headers)
    data = response.json()
    
    count = data.get("total_count", 0)
    results[year] = count
    
    print(f"{year}: {count}")
    
    time.sleep(2)  # avoid rate limiting

print("\nFinal Results:")
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import requests
#       2 import time
#       4 # 🔑 Replace with your GitHub token
#
# ModuleNotFoundError: No module named 'requests'

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ------------------------ --------------- 3/5 [certifi]
#    -------------------------------- ------- 4/5 [requests]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# ...

# %%
import requests
import time

# 🔑 Replace with your GitHub token
TOKEN = "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"

headers = {
    "Authorization": f"token {TOKEN}"
}

keyword = "generative art"
years = range(2010, 2024)

results = {}

for year in years:
    url = f"https://api.github.com/search/repositories?q={keyword}+created:{year}-01-01..{year}-12-31&per_page=1"
    
    response = requests.get(url, headers=headers)
    data = response.json()
    
    count = data.get("total_count", 0)
    results[year] = count
    
    print(f"{year}: {count}")
    
    time.sleep(2)  # avoid rate limiting

print("\nFinal Results:")
print(results)
# Out:
# 2010: 3
# 2011: 9
# 2012: 15
# 2013: 41
# 2014: 60
# 2015: 61
# 2016: 115
# 2017: 163
# 2018: 276
# 2019: 360
# 2020: 521
# 2021: 959
# 2022: 1003
# 2023: 719
#
# Final Results:
# {2010: 3, 2011: 9, 2012: 15, 2013: 41, 2014: 60, 2015: 61, 2016: 115, 2017: 163, 2018: 276, 2019: 360, 2020: 521, 2021: 959, 2022: 1003, 2023: 719}

# %%
dataf={2010: 3, 2011: 9, 2012: 15, 2013: 41, 2014: 60, 2015: 61, 2016: 115, 2017: 163, 2018: 276, 2019: 360, 2020: 521, 2021: 959}

# %%
years=dataf.keys()

# %%
repocount=dataf.values()

# %%
import plotly.express as px

# %%
px.bar(x=years, y=repocount, title="GitHub Repositories Created with 'Generative Art' Keyword (2010-2021)", labels={"x": "Year", "y": "Repository Count"}, color_discrete_sequence=["#BE0A85"])
