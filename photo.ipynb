# %%
import plotly.express as px
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('query.csv')
print(df)
# Out:
#     decade  paintingCount
# 0     1800          10232
# 1     1810           7776
# 2     1820          10616
# 3     1830          13439
# 4     1840          15153
# 5     1850          21084
# 6     1860          17572
# 7     1870          23193
# 8     1880          28426
# 9     1890          28590
# 10    1900          34684
# 11    1910          33530
# 12    1920          30618
# 13    1930          28476
# 14    1940          25526
# 15    1950          28765
# 16    1960          32482
# 17    1970          26840
# 18    1980          26204
# 19    1990          18265
# 20    2000          15293
# 21    2010           5666
# 22    2020            156

# %%
df=df[:-1]
print(df)
# Out:
#     decade  paintingCount
# 0     1800          10232
# 1     1810           7776
# 2     1820          10616
# 3     1830          13439
# 4     1840          15153
# 5     1850          21084
# 6     1860          17572
# 7     1870          23193
# 8     1880          28426
# 9     1890          28590
# 10    1900          34684
# 11    1910          33530
# 12    1920          30618
# 13    1930          28476
# 14    1940          25526
# 15    1950          28765
# 16    1960          32482
# 17    1970          26840
# 18    1980          26204
# 19    1990          18265
# 20    2000          15293

# %%
plt=px.line(df,df2, x=df.decade, y=df.paintingCount, title='WIKIDATA: Painting Count by Decade')
plt.show()

# %%
df2= pd.read_csv('photo.csv')
print(df2)
# Out:
#     decade  photoCount
# 0     1800         845
# 1     1810           6
# 2     1820           5
# 3     1830          27
# 4     1840         300
# 5     1850        1244
# 6     1860        2313
# 7     1870        9950
# 8     1880        5249
# 9     1890        1962
# 10    1900        7361
# 11    1910        3874
# 12    1920        4095
# 13    1930        3655
# 14    1940        3272
# 15    1950        4793
# 16    1960        2574
# 17    1970        2858
# 18    1980        2592
# 19    1990        2506
# 20    2000        2606
# 21    2010         617
# 22    2020          23

# %%
df2 = df2[:-2]
print(df2)
# Out:
#     decade  photoCount
# 0     1800         845
# 1     1810           6
# 2     1820           5
# 3     1830          27
# 4     1840         300
# 5     1850        1244
# 6     1860        2313
# 7     1870        9950
# 8     1880        5249
# 9     1890        1962
# 10    1900        7361
# 11    1910        3874
# 12    1920        4095
# 13    1930        3655
# 14    1940        3272
# 15    1950        4793
# 16    1960        2574
# 17    1970        2858
# 18    1980        2592
# 19    1990        2506
# 20    2000        2606

# %%
dfcombined = pd.merge(df, df2, on='decade')
print(dfcombined)
# Out:
#     decade  paintingCount  photoCount
# 0     1800          10232         845
# 1     1810           7776           6
# 2     1820          10616           5
# 3     1830          13439          27
# 4     1840          15153         300
# 5     1850          21084        1244
# 6     1860          17572        2313
# 7     1870          23193        9950
# 8     1880          28426        5249
# 9     1890          28590        1962
# 10    1900          34684        7361
# 11    1910          33530        3874
# 12    1920          30618        4095
# 13    1930          28476        3655
# 14    1940          25526        3272
# 15    1950          28765        4793
# 16    1960          32482        2574
# 17    1970          26840        2858
# 18    1980          26204        2592
# 19    1990          18265        2506
# 20    2000          15293        2606

# %%
plt=px.line(dfcombined, x=dfcombined.decade, y=[dfcombined.paintingCount, dfcombined.photoCount], title='WIKIDATA: Painting Count vs Photograph Count by Decade')
plt.show()

# %%
import pandas as pd
tsv_file='title.basics.tsv'
csv_table=pd.read_csv(tsv_file, sep='\t')
csv_table.to_csv('title.basics.csv', index=False)
df3=pd.read_csv('title.basics.csv')

# %%
print(df3)
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 12293729  tt9916848  tvEpisode              Episode #3.17
# 12293730  tt9916850  tvEpisode              Episode #3.19
# 12293731  tt9916852  tvEpisode              Episode #3.20
# 12293732  tt9916856      short                   The Wind
# 12293733  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita        0      1894      \N              1
# 1            Le clown et ses chiens        0      1892      \N              5
# ...
